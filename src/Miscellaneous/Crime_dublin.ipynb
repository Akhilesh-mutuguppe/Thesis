# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('E:\\MCM\\Practicum docs\\Final_documents\\datasets\\Crime_area_code.csv')

# %%
df
# Out:
#       id Area_code            Station                       Divisions  \
# 0   2033       D01  Fitzgibbon Street   D.M.R. North Central Division
# 1   2032       D01       Store Street   D.M.R. North Central Division
# 2    201       D02      Pearse Street   D.M.R. South Central Division
# 3   2027       D03           Clontarf        D.M.R. Northern Division
# 4    205       D04         Donnybrook   D.M.R. South Central Division
# 5    206       D04          Irishtown   D.M.R. South Central Division
# 6   2023       D05            Coolock        D.M.R. Northern Division
# 7   2026       D05             Raheny        D.M.R. Northern Division
# 8   2017       D06          Rathmines        D.M.R. Southern Division
# 9   2018       D06           Terenure        D.M.R. Southern Division
# 10  2035       D07   Bridewell Dublin   D.M.R. North Central Division
# 11  2028       D07              Cabra         D.M.R. Western Division
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'Area_code', 'Station', 'Divisions',
#        'Attempts or threats to murder, assaults, harassments and related offences 2007',
#        'Attempts or threats to murder, assaults, harassments and related offences 2008',
#        'Attempts or threats to murder, assaults, harassments and related offences 2009',
#        'Attempts or threats to murder, assaults, harassments and related offences 2010',
#        'Attempts or threats to murder, assaults, harassments and related offences 2011',
#        'Attempts or threats to murder, assaults, harassments and related offences 2012',
#        ...
#        'Offences against government, justice procedures and organisation of crime 2009',
#        'Offences against government, justice procedures and organisation of crime 2010',
#        'Offences against government, justice procedures and organisation of crime 2011',
#        'Offences against government, justice procedures and organisation of crime 2012',
# ...

# %%
df.drop(columns=['id'],inplace = True)

# %%
df.head()
# Out:
#   Area_code            Station                       Divisions  \
# 0       D01  Fitzgibbon Street   D.M.R. North Central Division
# 1       D01       Store Street   D.M.R. North Central Division
# 2       D02      Pearse Street   D.M.R. South Central Division
# 3       D03           Clontarf        D.M.R. Northern Division
# 4       D04         Donnybrook   D.M.R. South Central Division
#
#    Attempts or threats to murder, assaults, harassments and related offences 2007  \
# 0                                                130
# 1                                                279
# 2                                                525
# 3                                                 93
# 4                                                 67
#
#    Attempts or threats to murder, assaults, harassments and related offences 2008  \
# 0                                                161
# 1                                                284
# ...

# %%
df.sum(axis=1, skipna=True)
# Out:
# 0      27062
# 1     102171
# 2     112308
# 3      21011
# 4      19659
# 5      15593
# 6      35125
# 7      12039
# 8      21675
# 9      15336
# 10     67347
# 11     16717
# 12     28542
# 13     37812
# 14     31377
# 15     24071
# 16     27194
# 17     35653
# 18     17934
# 19     19417
# 20      9754
# 21     33811
# 22     66124
# 23     29246
# 24     12941
# 25     13741
# 26     25599
# 27     31616
# 28     29675
# 29      7214
# 30     69330
# dtype: int64

# %%
df1 = df.iloc[:,0:15]

# %%
df1.head()
# Out:
#   Area_code            Station                       Divisions  \
# 0       D01  Fitzgibbon Street   D.M.R. North Central Division
# 1       D01       Store Street   D.M.R. North Central Division
# 2       D02      Pearse Street   D.M.R. South Central Division
# 3       D03           Clontarf        D.M.R. Northern Division
# 4       D04         Donnybrook   D.M.R. South Central Division
#
#    Attempts or threats to murder, assaults, harassments and related offences 2007  \
# 0                                                130
# 1                                                279
# 2                                                525
# 3                                                 93
# 4                                                 67
#
#    Attempts or threats to murder, assaults, harassments and related offences 2008  \
# 0                                                161
# 1                                                284
# ...

# %%
df1['Total Attempts or threats to murder, assaults, harassments and related offences'] = df1.sum(axis=1)
df1
# Out:
#    Area_code            Station                       Divisions  \
# 0        D01  Fitzgibbon Street   D.M.R. North Central Division
# 1        D01       Store Street   D.M.R. North Central Division
# 2        D02      Pearse Street   D.M.R. South Central Division
# 3        D03           Clontarf        D.M.R. Northern Division
# 4        D04         Donnybrook   D.M.R. South Central Division
# 5        D04          Irishtown   D.M.R. South Central Division
# 6        D05            Coolock        D.M.R. Northern Division
# 7        D05             Raheny        D.M.R. Northern Division
# 8        D06          Rathmines        D.M.R. Southern Division
# 9        D06           Terenure        D.M.R. Southern Division
# 10       D07   Bridewell Dublin   D.M.R. North Central Division
# 11       D07              Cabra         D.M.R. Western Division
# 12       D07           Mountjoy   D.M.R. North Central Division
# 13       D08       Kevin Street   D.M.R. South Central Division
# ...

# %%
data_merged = pd.DataFrame(columns = ['Attempts or threats to murder, assaults, harassments and related offences',
                                      'Dangerous or negligent acts',
                                     'Kidnapping and related offences',
                                     'Robbery, extortion and hijacking offences',
                                     'Burglary and related offences',
                                     'Theft and related offences',
                                     'Fraud, deception and related offences',
                                     'Controlled drug offences 2008','Weapons and Explosives Offences',
                                     'Damage to property and to the environment 2008','Public order and other social code offences',
                                     'Offences against government, justice procedures and organisation of crime'])

# %%
##col_list1 = list(df1)
##col_list1
##df_merge['Total Attempts or threats to murder, assaults, harassments and related offences'] = df1[col_list1].sum(axis=1)
##df_merged = df1[col_list1].sum(axis=1)

# %%
df2 = df.iloc[:,15:27]

# %%
df2.head()
# Out:
#    Dangerous or negligent acts 2007  Dangerous or negligent acts 2008  \
# 0                                93                               119
# 1                               199                               227
# 2                               246                               152
# 3                                95                                97
# 4                               133                               126
#
#    Dangerous or negligent acts 2009  Dangerous or negligent acts 2010  \
# 0                               105                                72
# 1                               154                               103
# 2                               147                               110
# 3                               120                                66
# 4                                81                                49
#
#    Dangerous or negligent acts 2011  Dangerous or negligent acts 2012  \
# ...

# %%
df2['Total Dangerous or negligent acts'] = df2.sum(axis=1)
df2
# Out:
#     Dangerous or negligent acts 2007  Dangerous or negligent acts 2008  \
# 0                                 93                               119
# 1                                199                               227
# 2                                246                               152
# 3                                 95                                97
# 4                                133                               126
# 5                                 72                                40
# 6                                183                               234
# 7                                 50                                72
# 8                                 68                                79
# 9                                 90                               104
# 10                               152                               145
# 11                                88                               103
# ...

# %%
df3 = df.iloc[:,27:40]

# %%
df3.head()
# Out:
#    Kidnapping and related offences 2006  Kidnapping and related offences 2007  \
# 0                                     1                                     0
# 1                                     1                                     1
# 2                                     1                                     4
# 3                                     0                                     1
# 4                                     0                                     1
#
#    Kidnapping and related offences 2008  Kidnapping and related offences 2009  \
# 0                                     0                                     1
# 1                                     3                                     3
# 2                                     3                                     5
# 3                                     0                                     0
# 4                                     0                                     1
#
# ...

# %%
df3['Total Kidnapping and related offences'] = df3.sum(axis=1)
df3.head()
# Out:
#    Kidnapping and related offences 2006  Kidnapping and related offences 2007  \
# 0                                     1                                     0
# 1                                     1                                     1
# 2                                     1                                     4
# 3                                     0                                     1
# 4                                     0                                     1
#
#    Kidnapping and related offences 2008  Kidnapping and related offences 2009  \
# 0                                     0                                     1
# 1                                     3                                     3
# 2                                     3                                     5
# 3                                     0                                     0
# 4                                     0                                     1
#
# ...

# %%
df4 = df.iloc[:,40:52]
df4.head()
# Out:
#    Robbery, extortion and hijacking offences 2007  \
# 0                                              52
# 1                                              83
# 2                                             145
# 3                                              45
# 4                                              14
#
#    Robbery, extortion and hijacking offences 2008  \
# 0                                              63
# 1                                              84
# 2                                             118
# 3                                              52
# 4                                              20
#
#    Robbery, extortion and hijacking offences 2009  \
# 0                                              68
# 1                                             102
# 2                                             115
# 3                                              31
# 4                                              16
#
# ...

# %%
df4['Total Robbery, extortion and hijacking offences'] = df4.sum(axis=1)
df4.head()
# Out:
#    Robbery, extortion and hijacking offences 2007  \
# 0                                              52
# 1                                              83
# 2                                             145
# 3                                              45
# 4                                              14
#
#    Robbery, extortion and hijacking offences 2008  \
# 0                                              63
# 1                                              84
# 2                                             118
# 3                                              52
# 4                                              20
#
#    Robbery, extortion and hijacking offences 2009  \
# 0                                              68
# 1                                             102
# 2                                             115
# 3                                              31
# 4                                              16
#
# ...

# %%
df5 = df.iloc[:,52:64]
df5.head()
# Out:
#    Burglary and related offences 2007  Burglary and related offences 2008  \
# 0                                 218                                 205
# 1                                 309                                 339
# 2                                 577                                 700
# 3                                 240                                 282
# 4                                 242                                 283
#
#    Burglary and related offences 2009  Burglary and related offences 2010  \
# 0                                 242                                 217
# 1                                 311                                 299
# 2                                 560                                 489
# 3                                 388                                 354
# 4                                 210                                 226
#
# ...

# %%
df5['Total Burglary and related offences'] = df5.sum(axis=1)
df5.head()
# Out:
#    Burglary and related offences 2007  Burglary and related offences 2008  \
# 0                                 218                                 205
# 1                                 309                                 339
# 2                                 577                                 700
# 3                                 240                                 282
# 4                                 242                                 283
#
#    Burglary and related offences 2009  Burglary and related offences 2010  \
# 0                                 242                                 217
# 1                                 311                                 299
# 2                                 560                                 489
# 3                                 388                                 354
# 4                                 210                                 226
#
# ...

# %%
df6 = df.iloc[:,64:76]
df6.head()
# Out:
#    Theft and related offences 2007  Theft and related offences 2008  \
# 0                              721                              841
# 1                             4352                             4733
# 2                             4001                             3952
# 3                              671                              656
# 4                              713                              602
#
#    Theft and related offences 2009  Theft and related offences 2010  \
# 0                              745                              851
# 1                             4205                             4963
# 2                             3674                             3712
# 3                              582                              738
# 4                              681                              712
#
#    Theft and related offences 2011  Theft and related offences 2012  \
# 0                             1030                              868
# ...

# %%
df6['Total Theft and related offences'] = df6.sum(axis=1)
df6.head()
# Out:
#    Theft and related offences 2007  Theft and related offences 2008  \
# 0                              721                              841
# 1                             4352                             4733
# 2                             4001                             3952
# 3                              671                              656
# 4                              713                              602
#
#    Theft and related offences 2009  Theft and related offences 2010  \
# 0                              745                              851
# 1                             4205                             4963
# 2                             3674                             3712
# 3                              582                              738
# 4                              681                              712
#
#    Theft and related offences 2011  Theft and related offences 2012  \
# 0                             1030                              868
# ...

# %%
df7 = df.iloc[:,76:88]
df7.head()
# Out:
#    Fraud, deception and related offences 2007  \
# 0                                          42
# 1                                         231
# 2                                         459
# 3                                          58
# 4                                          64
#
#    Fraud, deception and related offences 2008  \
# 0                                          90
# 1                                         203
# 2                                         273
# 3                                          25
# 4                                          64
#
#    Fraud, deception and related offences 2009  \
# 0                                          52
# 1                                         200
# 2                                         219
# 3                                          38
# 4                                          33
#
#    Fraud, deception and related offences 2010  \
# 0                                          37
# ...

# %%
df7['Total Fraud, deception and related offences'] = df7.sum(axis=1)
df7.head()
# Out:
#    Fraud, deception and related offences 2007  \
# 0                                          42
# 1                                         231
# 2                                         459
# 3                                          58
# 4                                          64
#
#    Fraud, deception and related offences 2008  \
# 0                                          90
# 1                                         203
# 2                                         273
# 3                                          25
# 4                                          64
#
#    Fraud, deception and related offences 2009  \
# 0                                          52
# 1                                         200
# 2                                         219
# 3                                          38
# 4                                          33
#
#    Fraud, deception and related offences 2010  \
# 0                                          37
# ...

# %%
df8 = df.iloc[:,88:100]
df8.head()
# Out:
#    Controlled drug offences 2007  Controlled drug offences 2008  \
# 0                            128                            134
# 1                            319                            351
# 2                            449                            506
# 3                             88                            101
# 4                             77                             75
#
#    Controlled drug offences 2009  Controlled drug offences 2010  \
# 0                            182                            165
# 1                            460                            471
# 2                            545                            356
# 3                            108                             93
# 4                            100                             71
#
#    Controlled drug offences 2011  Controlled drug offences 2012  \
# 0                            134                            160
# ...

# %%
df8['Total Controlled drug offences '] = df8.sum(axis=1)
df8.head()
# Out:
#    Controlled drug offences 2007  Controlled drug offences 2008  \
# 0                            128                            134
# 1                            319                            351
# 2                            449                            506
# 3                             88                            101
# 4                             77                             75
#
#    Controlled drug offences 2009  Controlled drug offences 2010  \
# 0                            182                            165
# 1                            460                            471
# 2                            545                            356
# 3                            108                             93
# 4                            100                             71
#
#    Controlled drug offences 2011  Controlled drug offences 2012  \
# 0                            134                            160
# ...

# %%
df9 = df.iloc[:,100:112]
df9.head()
# Out:
#    Weapons and Explosives Offences 2007  Weapons and Explosives Offences 2008  \
# 0                                    50                                    60
# 1                                   132                                   147
# 2                                    93                                   121
# 3                                    22                                    28
# 4                                    15                                    15
#
#    Weapons and Explosives Offences 2009  Weapons and Explosives Offences 2010  \
# 0                                    63                                    95
# 1                                   118                                   155
# 2                                   132                                   145
# 3                                    33                                    33
# 4                                    21                                    29
#
# ...

# %%
df9['Total Weapons and Explosives Offences '] = df9.sum(axis=1)
df9.head()
# Out:
#    Weapons and Explosives Offences 2007  Weapons and Explosives Offences 2008  \
# 0                                    50                                    60
# 1                                   132                                   147
# 2                                    93                                   121
# 3                                    22                                    28
# 4                                    15                                    15
#
#    Weapons and Explosives Offences 2009  Weapons and Explosives Offences 2010  \
# 0                                    63                                    95
# 1                                   118                                   155
# 2                                   132                                   145
# 3                                    33                                    33
# 4                                    21                                    29
#
# ...

# %%
df10 = df.iloc[:,112:124]
df10.head()
# Out:
#    Damage to property and to the environment 2007  \
# 0                                             359
# 1                                             572
# 2                                             613
# 3                                             343
# 4                                             251
#
#    Damage to property and to the environment 2008  \
# 0                                             464
# 1                                             672
# 2                                             584
# 3                                             327
# 4                                             219
#
#    Damage to property and to the environment 2009  \
# 0                                             398
# 1                                             737
# 2                                             539
# 3                                             367
# 4                                             230
#
# ...

# %%
df10['Total Damage to property and to the environment '] = df10.sum(axis=1)
df10.head()
# Out:
#    Damage to property and to the environment 2007  \
# 0                                             359
# 1                                             572
# 2                                             613
# 3                                             343
# 4                                             251
#
#    Damage to property and to the environment 2008  \
# 0                                             464
# 1                                             672
# 2                                             584
# 3                                             327
# 4                                             219
#
#    Damage to property and to the environment 2009  \
# 0                                             398
# 1                                             737
# 2                                             539
# 3                                             367
# 4                                             230
#
# ...

# %%
df11 = df.iloc[:,124:136]
df11.head()
# Out:
#    Public order and other social code offences 2007  \
# 0                                               420
# 1                                              1854
# 2                                              2553
# 3                                               298
# 4                                               312
#
#    Public order and other social code offences 2008  \
# 0                                               498
# 1                                              2444
# 2                                              2960
# 3                                               379
# 4                                               347
#
#    Public order and other social code offences 2009  \
# 0                                               442
# 1                                              1564
# 2                                              2380
# 3                                               342
# 4                                               300
#
# ...

# %%
df11['Total Public order and other social code offences '] = df11.sum(axis=1)
df11.head()
# Out:
#    Public order and other social code offences 2007  \
# 0                                               420
# 1                                              1854
# 2                                              2553
# 3                                               298
# 4                                               312
#
#    Public order and other social code offences 2008  \
# 0                                               498
# 1                                              2444
# 2                                              2960
# 3                                               379
# 4                                               347
#
#    Public order and other social code offences 2009  \
# 0                                               442
# 1                                              1564
# 2                                              2380
# 3                                               342
# 4                                               300
#
# ...

# %%
df12 = df.iloc[:,136:148]
df12.head()
# Out:
#    Offences against government, justice procedures and organisation of crime 2007  \
# 0                                                 73
# 1                                                413
# 2                                                107
# 3                                                 24
# 4                                                 19
#
#    Offences against government, justice procedures and organisation of crime 2008  \
# 0                                                 29
# 1                                                375
# 2                                                162
# 3                                                 21
# 4                                                 13
#
#    Offences against government, justice procedures and organisation of crime 2009  \
# 0                                                 18
# 1                                                110
# 2                                                273
# ...

# %%
df12['Total Offences against government, justice procedures and organisation of crime '] = df12.sum(axis=1)
df12.head()
# Out:
#    Offences against government, justice procedures and organisation of crime 2007  \
# 0                                                 73
# 1                                                413
# 2                                                107
# 3                                                 24
# 4                                                 19
#
#    Offences against government, justice procedures and organisation of crime 2008  \
# 0                                                 29
# 1                                                375
# 2                                                162
# 3                                                 21
# 4                                                 13
#
#    Offences against government, justice procedures and organisation of crime 2009  \
# 0                                                 18
# 1                                                110
# 2                                                273
# ...

# %%
#t_d = pd.concat([test,test_1],axis=1)
crime_data = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12],axis=1)

# %%
crime_data.head()
# Out:
#   Area_code            Station                       Divisions  \
# 0       D01  Fitzgibbon Street   D.M.R. North Central Division
# 1       D01       Store Street   D.M.R. North Central Division
# 2       D02      Pearse Street   D.M.R. South Central Division
# 3       D03           Clontarf        D.M.R. Northern Division
# 4       D04         Donnybrook   D.M.R. South Central Division
#
#    Attempts or threats to murder, assaults, harassments and related offences 2007  \
# 0                                                130
# 1                                                279
# 2                                                525
# 3                                                 93
# 4                                                 67
#
#    Attempts or threats to murder, assaults, harassments and related offences 2008  \
# 0                                                161
# 1                                                284
# ...

# %%
#t_d = t_d.loc[:,['e','k']]
crime_data = crime_data.loc[:,['Area_code','Station','Total Attempts or threats to murder, assaults, harassments and related offences',
                                     'Total Dangerous or negligent acts',
                                     'Total Kidnapping and related offences',
                                     'Total Robbery, extortion and hijacking offences',
                                     'Total Burglary and related offences',
                                     'Total Theft and related offences','Total Fraud, deception and related offences',
                              'Total Controlled drug offences ','Total Weapons and Explosives Offences ',
                              'Total Damage to property and to the environment ','Total Public order and other social code offences ',
                              'Total Offences against government, justice procedures and organisation of crime ']]

# %%
crime_data.to_excel(r'E:/MCM/Practicum docs/Final_documents/datasets/crime_data.xlsx', index = False)
